# %%
import sys
print("Python:", sys.executable)
import numpy, pandas
print("NumPy", numpy.__version__, "Pandas", pandas.__version__)
# Out:
# Python: C:\Users\Dell\AppData\Local\Programs\Python\Python310\python.exe
# NumPy 1.26.2 Pandas 2.1.4

# %%
import sys, os
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from src.ml.model_training import prepare_data, train_linear_regression, evaluate_model
# Out:
# WARNING:tensorflow:From C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import pandas as pd
df = pd.read_csv(os.path.join(project_root, "data", C://Users//Dell//Downloads//OneDrive//Desktop//project_1//data//AAPL_stock_data.csv), index_col="Date", parse_dates=True)
df.head()
# Out:
#   Cell In[8], line 2
#     df = pd.read_csv(os.path.join(project_root, "data", C://Users//Dell//Downloads//OneDrive//Desktop//project_1//data//AAPL_stock_data.csv), index_col="Date", parse_dates=True)
#                                                          ^
# SyntaxError: invalid syntax
