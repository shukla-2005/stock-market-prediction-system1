# %% [markdown]
# # Stock Market Prediction Analysis
#
# This notebook contains the analysis and evaluation of the stock prediction models.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib
from tensorflow.keras.models import load_model

# Load data
df = pd.read_csv('../data/AAPL_preprocessed.csv', index_col='Date', parse_dates=True)
print(df.head())

# %%
# Load models and evaluate
models = ['lr', 'rf', 'xgb', 'lstm']
results = {}

for model_name in models:
    if model_name == 'lstm':
        model = load_model(f'../models/{model_name}_model.h5')
    else:
        model = joblib.load(f'../models/{model_name}_model.pkl')
    
    # Evaluation code here
    results[model_name] = {'rmse': 0.023, 'mae': 0.018, 'r2': 0.94}  # Placeholder

results_df = pd.DataFrame(results).T
print(results_df)

# %%
# Visualization
plt.figure(figsize=(12, 6))
plt.plot(df.index[-100:], df['Close'][-100:], label='Actual')
# Add predictions
plt.legend()
plt.title('Stock Price Prediction vs Actual')
plt.show()
